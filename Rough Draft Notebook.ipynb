# %%
# Import libraries and dependencies
import os
import pandas as pd
import alpaca_trade_api as tradeapi
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from yahoo_fin.stock_info import get_data
# Out:
# 2024-01-15 14:54:02.241586: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Get historical prices from first candle to the most recent candle
hist_df = get_data('DIS', index_as_date=False)

# Show the first 5 rows of our dataframe
hist_df.head()
# Out:
#         date      open      high       low     close  adjclose   volume ticker
# 0 1970-03-25  0.734737  0.757216  0.734737  0.750151  0.497616  2627471    DIS
# 1 1970-03-26  0.750151  0.752720  0.740517  0.752720  0.499319  2082514    DIS
# 2 1970-03-30  0.754005  0.765565  0.754005  0.762996  0.506136  1109377    DIS
# 3 1970-03-31  0.762996  0.764923  0.750151  0.757858  0.502728  1868424    DIS
# 4 1970-04-01  0.757858  0.778410  0.747582  0.775841  0.514657  2627471    DIS

# %%
hist_df.tail()
# Out:
#             date       open       high        low      close   adjclose  \
# 13566 2024-01-08  91.550003  91.940002  91.000000  91.550003  91.550003
# 13567 2024-01-09  91.050003  91.099998  89.599998  89.669998  89.669998
# 13568 2024-01-10  89.820000  89.820000  88.879997  89.290001  89.290001
# 13569 2024-01-11  89.389999  89.779999  88.690002  89.449997  89.449997
# 13570 2024-01-12  89.650002  90.830002  89.650002  90.349998  90.349998
#
#          volume ticker
# 13566  11103700    DIS
# 13567  11255100    DIS
# 13568  15091600    DIS
# 13569   9642200    DIS
# 13570  11912800    DIS

# %% [markdown]
# Note that I want the date as a column (not as an index), so I coded index_as_date=False above.

# %%
hist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13571 entries, 0 to 13570
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      13571 non-null  datetime64[ns]
#  1   open      13571 non-null  float64
#  2   high      13571 non-null  float64
#  3   low       13571 non-null  float64
#  4   close     13571 non-null  float64
#  5   adjclose  13571 non-null  float64
#  6   volume    13571 non-null  int64
#  7   ticker    13571 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 848.3+ KB

# %%
hist_df.dtypes
# Out:
# date        datetime64[ns]
# open               float64
# high               float64
# low                float64
# close              float64
# adjclose           float64
# volume               int64
# ticker              object
# dtype: object

# %%
prices = hist_df.drop(['adjclose'], axis=1)
prices.head()
# Out:
#         date      open      high       low     close   volume ticker
# 0 1970-03-25  0.734737  0.757216  0.734737  0.750151  2627471    DIS
# 1 1970-03-26  0.750151  0.752720  0.740517  0.752720  2082514    DIS
# 2 1970-03-30  0.754005  0.765565  0.754005  0.762996  1109377    DIS
# 3 1970-03-31  0.762996  0.764923  0.750151  0.757858  1868424    DIS
# 4 1970-04-01  0.757858  0.778410  0.747582  0.775841  2627471    DIS

# %%
# Add difference between closing price and opening price
# NOTE: O-to-C is the length of the candle's body

prices['O-to-C'] = prices['close'] - prices['open']
prices['O-to-C']
# Out:
# 0        0.015414
# 1        0.002569
# 2        0.008991
# 3       -0.005138
# 4        0.017983
#            ...
# 13566    0.000000
# 13567   -1.380005
# 13568   -0.529999
# 13569    0.059998
# 13570    0.699997
# Name: O-to-C, Length: 13571, dtype: float64

# %%
# Add 20-Day moving average for Open-to-Close column 

prices['OC-20D-Mean'] = prices['O-to-C'].rolling(20).mean()
prices['OC-20D-Mean']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 13566    0.107499
# 13567    0.000499
# 13568    0.000499
# 13569    0.055999
# 13570    0.007999
# Name: OC-20D-Mean, Length: 13571, dtype: float64

# %%
# Calculate the % change of the current day's O-to-C relative to the moving average
prices['OC-%-from-20D-Mean'] = 100*(prices['O-to-C'] - prices['OC-20D-Mean'])/prices['OC-20D-Mean']

# %%
# Get the maximum OC compared to the recent 10 candles (including the current candle)
prices['MaxOC_Prev10'] = prices['O-to-C'].rolling(10).max()
prices['MaxOC_Prev10']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 13566    1.419998
# 13567    1.419998
# 13568    1.419998
# 13569    1.419998
# 13570    1.419998
# Name: MaxOC_Prev10, Length: 13571, dtype: float64

# %%
# Add 20-Day moving average for volume 
prices['Volume-20D-Mean'] = prices['volume'].rolling(20).mean()
prices['Volume-20D-Mean']
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 13566    10938195.0
# 13567    11026190.0
# 13568    11240220.0
# 13569    11061410.0
# 13570    11148390.0
# Name: Volume-20D-Mean, Length: 13571, dtype: float64

# %%
# Calculate the % change of the current volume relative to the moving average
prices['Volume-%-from-20D-Mean'] = 100*(prices['volume'] - prices['Volume-20D-Mean'])/prices['Volume-20D-Mean']
prices['Volume-%-from-20D-Mean']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 13566     1.513092
# 13567     2.076057
# 13568    34.264276
# 13569   -12.830281
# 13570     6.856685
# Name: Volume-%-from-20D-Mean, Length: 13571, dtype: float64

# %%
# Print the columns for easy copy-pasting
prices.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'ticker', 'O-to-C',
#        'OC-20D-Mean', 'OC-%-from-20D-Mean', 'MaxOC_Prev10', 'Volume-20D-Mean',
#        'Volume-%-from-20D-Mean'],
#       dtype='object')

# %%
# Rearrange the columns for our dataframe
prices = prices[['ticker', 'date', 'open', 'high', 'low', 'close', 
                 'O-to-C', 'OC-20D-Mean', 'volume', 'Volume-20D-Mean', 
                 'MaxOC_Prev10', 'Volume-%-from-20D-Mean', 'OC-%-from-20D-Mean', 
                ]]

# Show the 10 most recent rows
prices.tail(10)
# Out:
#       ticker       date       open       high        low      close    O-to-C  \
# 13561    DIS 2023-12-29  90.120003  90.599998  89.860001  90.290001  0.169998
# 13562    DIS 2024-01-02  90.099998  91.480003  89.730003  90.709999  0.610001
# 13563    DIS 2024-01-03  90.230003  92.080002  90.000000  91.650002  1.419998
# 13564    DIS 2024-01-04  91.940002  91.940002  90.000000  90.559998 -1.380005
# 13565    DIS 2024-01-05  90.410004  91.320000  90.360001  90.900002  0.489998
# 13566    DIS 2024-01-08  91.550003  91.940002  91.000000  91.550003  0.000000
# 13567    DIS 2024-01-09  91.050003  91.099998  89.599998  89.669998 -1.380005
# 13568    DIS 2024-01-10  89.820000  89.820000  88.879997  89.290001 -0.529999
# 13569    DIS 2024-01-11  89.389999  89.779999  88.690002  89.449997  0.059998
# 13570    DIS 2024-01-12  89.650002  90.830002  89.650002  90.349998  0.699997
#
#        OC-20D-Mean    volume  Volume-20D-Mean  MaxOC_Prev10  \
# 13561     0.053999   9201300       11077480.0      1.290001
# 13562     0.092499  10587600       11012255.0      1.290001
# 13563     0.157999  11929800       10978605.0      1.419998
# 13564     0.129999  12087400       10965125.0      1.419998
# 13565     0.134999   9084400       10896245.0      1.419998
# 13566     0.107499  11103700       10938195.0      1.419998
# 13567     0.000499  11255100       11026190.0      1.419998
# 13568     0.000499  15091600       11240220.0      1.419998
# 13569     0.055999   9642200       11061410.0      1.419998
# 13570     0.007999  11912800       11148390.0      1.419998
#
#        Volume-%-from-20D-Mean  OC-%-from-20D-Mean
# 13561              -16.936885          214.815338
# 13562               -3.856204          559.466102
# 13563                8.664079          798.738486
# 13564               10.234949        -1161.552186
# 13565              -16.628160          262.964868
# 13566                1.513092         -100.000000
# 13567                2.076057      -276886.534047
# 13568               34.264276      -106320.183486
# 13569              -12.830281            7.140424
# 13570                6.856685         8651.430752

# %%
prices = prices.dropna()
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13550 entries, 19 to 13570
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ticker                  13550 non-null  object
#  1   date                    13550 non-null  datetime64[ns]
#  2   open                    13550 non-null  float64
#  3   high                    13550 non-null  float64
#  4   low                     13550 non-null  float64
#  5   close                   13550 non-null  float64
#  6   O-to-C                  13550 non-null  float64
#  7   OC-20D-Mean             13550 non-null  float64
#  8   volume                  13550 non-null  int64
#  9   Volume-20D-Mean         13550 non-null  float64
#  10  MaxOC_Prev10            13550 non-null  float64
#  11  Volume-%-from-20D-Mean  13550 non-null  float64
#  12  OC-%-from-20D-Mean      13550 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# Here are our conditions, find every candle that:
#
# -is green (i.e. the closing price is higher than the opening price);
# -has a body that is longest in 10 days;
# -has a body that is at least 100% longer than the average of the previous 20 candles (including the current candle); and
# -has a volume that is at least 50% higher than the average of the previous 20 candles (including the current candle).

# %%
#Code for Breakout condition "is green"
prices['O-to-C'] >= 0.0
# Out:
# 19       False
# 20       False
# 21       False
# 22       False
# 23        True
#          ...
# 13566     True
# 13567    False
# 13568    False
# 13569     True
# 13570     True
# Name: O-to-C, Length: 13550, dtype: bool

# %%
#Code for Breakout condition "has a body that is longest in 10 days"
prices['O-to-C'] == prices['MaxOC_Prev10']
# Out:
# 19       False
# 20       False
# 21       False
# 22       False
# 23        True
#          ...
# 13566    False
# 13567    False
# 13568    False
# 13569    False
# 13570    False
# Length: 13550, dtype: bool

# %%
#Code for Breakout condition "has a body that is at least 100% longer than the average of the previous 20 candles"
prices['OC-%-from-20D-Mean'] >= 100.0
# Out:
# 19        True
# 20        True
# 21        True
# 22        True
# 23       False
#          ...
# 13566    False
# 13567    False
# 13568    False
# 13569    False
# 13570     True
# Name: OC-%-from-20D-Mean, Length: 13550, dtype: bool

# %%
#Code for Breakout condition "has a volume that is at least 50% higher than the average of the previous 20 candles"
prices['Volume-%-from-20D-Mean'] >= 50.0
# Out:
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
#          ...
# 13566    False
# 13567    False
# 13568    False
# 13569    False
# 13570    False
# Name: Volume-%-from-20D-Mean, Length: 13550, dtype: bool

# %%
#Putting it all together 
condition = (prices['O-to-C'] >= 0.0) & (prices['O-to-C'] == prices['MaxOC_Prev10']) & (prices['OC-%-from-20D-Mean'] >= 100.0) & (prices['Volume-%-from-20D-Mean'] >= 50.0) 
breakouts = prices[condition]
breakouts.head()
# Out:
#     ticker       date      open      high       low     close    O-to-C  \
# 160    DIS 1970-11-09  0.657667  0.692991  0.657667  0.685926  0.028259
# 169    DIS 1970-11-20  0.681430  0.719323  0.681430  0.714827  0.033397
# 237    DIS 1971-03-02  0.964663  1.008337  0.964663  1.001914  0.037251
# 270    DIS 1971-04-19  1.082838  1.127796  1.082838  1.114951  0.032113
# 275    DIS 1971-04-26  1.172753  1.226702  1.172753  1.226702  0.053949
#
#      OC-20D-Mean   volume  Volume-20D-Mean  MaxOC_Prev10  \
# 160     0.003821  8875013       2111708.15      0.028259
# 169     0.005106  5644197       2952498.80      0.033397
# 237     0.005523  6198885       3335428.30      0.037251
# 270     0.001349  3396249       1900050.65      0.032113
# 275     0.005523  3483832       1909295.50      0.053949
#
#      Volume-%-from-20D-Mean  OC-%-from-20D-Mean
# 160              320.276495          639.483478
# 169               91.166784          554.073741
# 237               85.849745          574.421290
# 270               78.745182         2280.949435
# 275               82.466884          876.744537

# %%
#Creating a new column so we can assign binary values
prices['NewColumn'] = np.where(condition, 1, 0)
prices
# Out:
#       ticker       date       open       high        low      close    O-to-C  \
# 19       DIS 1970-04-22   0.675007   0.675650   0.661520   0.666016 -0.008991
# 20       DIS 1970-04-23   0.663447   0.663447   0.647391   0.655098 -0.008349
# 21       DIS 1970-04-24   0.653813   0.653813   0.634546   0.634546 -0.019267
# 22       DIS 1970-04-27   0.630692   0.630692   0.601148   0.604360 -0.026332
# 23       DIS 1970-04-28   0.604360   0.631977   0.601791   0.615920  0.011560
# ...      ...        ...        ...        ...        ...        ...       ...
# 13566    DIS 2024-01-08  91.550003  91.940002  91.000000  91.550003  0.000000
# 13567    DIS 2024-01-09  91.050003  91.099998  89.599998  89.669998 -1.380005
# 13568    DIS 2024-01-10  89.820000  89.820000  88.879997  89.290001 -0.529999
# 13569    DIS 2024-01-11  89.389999  89.779999  88.690002  89.449997  0.059998
# 13570    DIS 2024-01-12  89.650002  90.830002  89.650002  90.349998  0.699997
#
#        OC-20D-Mean    volume  Volume-20D-Mean  MaxOC_Prev10  \
# 19       -0.002762   3503294       2232377.15      0.007064
# 20       -0.003950   4184491       2310228.15      0.007064
# 21       -0.005042   4671059       2439655.40      0.007064
# 22       -0.006808   4515357       2609954.40      0.007064
# 23       -0.005973   4865687       2759817.55      0.011560
# ...            ...       ...              ...           ...
# 13566     0.107499  11103700      10938195.00      1.419998
# 13567     0.000499  11255100      11026190.00      1.419998
# 13568     0.000499  15091600      11240220.00      1.419998
# 13569     0.055999   9642200      11061410.00      1.419998
# 13570     0.007999  11912800      11148390.00      1.419998
#
#        Volume-%-from-20D-Mean  OC-%-from-20D-Mean  NewColumn
# 19                  56.931099          225.560014          0
# 20                  81.128907          111.374949          0
# 21                  91.463885          282.156637          0
# 22                  73.005207          286.791524          0
# 23                  76.304662         -293.541080          0
# ...                       ...                 ...        ...
# 13566                1.513092         -100.000000          0
# 13567                2.076057      -276886.534047          0
# 13568               34.264276      -106320.183486          0
# 13569              -12.830281            7.140424          0
# 13570                6.856685         8651.430752          0
#
# [13550 rows x 14 columns]

# %%
filtered_df = prices[prices['NewColumn'] == 1]
filtered_df
# Out:
#       ticker       date        open        high         low       close  \
# 160      DIS 1970-11-09    0.657667    0.692991    0.657667    0.685926
# 169      DIS 1970-11-20    0.681430    0.719323    0.681430    0.714827
# 237      DIS 1971-03-02    0.964663    1.008337    0.964663    1.001914
# 270      DIS 1971-04-19    1.082838    1.127796    1.082838    1.114951
# 275      DIS 1971-04-26    1.172753    1.226702    1.172753    1.226702
# ...      ...        ...         ...         ...         ...         ...
# 12833    DIS 2021-02-08  183.850006  190.639999  183.300003  190.000000
# 12842    DIS 2021-02-22  181.740005  194.020004  181.529999  191.759995
# 12852    DIS 2021-03-08  197.309998  203.020004  193.789993  201.910004
# 12939    DIS 2021-07-12  177.710007  184.990005  177.369995  184.380005
# 13527    DIS 2023-11-09   87.839996   91.209999   87.599998   90.339996
#
#           O-to-C  OC-20D-Mean    volume  Volume-20D-Mean  MaxOC_Prev10  \
# 160     0.028259     0.003821   8875013       2111708.15      0.028259
# 169     0.033397     0.005106   5644197       2952498.80      0.033397
# 237     0.037251     0.005523   6198885       3335428.30      0.037251
# 270     0.032113     0.001349   3396249       1900050.65      0.032113
# 275     0.053949     0.005523   3483832       1909295.50      0.053949
# ...          ...          ...       ...              ...           ...
# 12833   6.149994     0.135499  16085700       9846580.00      6.149994
# 12842  10.019989     0.724001  18799600      12451720.00     10.019989
# 12852   4.600006     0.321000  25093200      14514370.00      4.600006
# 12939   6.669998     0.356001  21835500       9597300.00      6.669998
# 13527   2.500000     0.163498  51062700      13652895.00      2.500000
#
#        Volume-%-from-20D-Mean  OC-%-from-20D-Mean  NewColumn
# 160                320.276495          639.483478          1
# 169                 91.166784          554.073741          1
# 237                 85.849745          574.421290          1
# 270                 78.745182         2280.949435          1
# 275                 82.466884          876.744537          1
# ...                       ...                 ...        ...
# 12833               63.363320         4438.780750          1
# 12842               50.979945         1283.975333          1
# 12852               72.885217         1333.024117          1
# 12939              127.517114         1773.588246          1
# 13527              274.006392         1429.067828          1
#
# [202 rows x 14 columns]

# %%
#Using isna fuction to find "infinity" values
filtered_df.isna()
# Out:
#        ticker   date   open   high    low  close  O-to-C  OC-20D-Mean  volume  \
# 160     False  False  False  False  False  False   False        False   False
# 169     False  False  False  False  False  False   False        False   False
# 237     False  False  False  False  False  False   False        False   False
# 270     False  False  False  False  False  False   False        False   False
# 275     False  False  False  False  False  False   False        False   False
# ...       ...    ...    ...    ...    ...    ...     ...          ...     ...
# 12833   False  False  False  False  False  False   False        False   False
# 12842   False  False  False  False  False  False   False        False   False
# 12852   False  False  False  False  False  False   False        False   False
# 12939   False  False  False  False  False  False   False        False   False
# 13527   False  False  False  False  False  False   False        False   False
#
#        Volume-20D-Mean  MaxOC_Prev10  Volume-%-from-20D-Mean  \
# 160              False         False                   False
# 169              False         False                   False
# 237              False         False                   False
# 270              False         False                   False
# 275              False         False                   False
# ...                ...           ...                     ...
# 12833            False         False                   False
# 12842            False         False                   False
# 12852            False         False                   False
# 12939            False         False                   False
# 13527            False         False                   False
#
#        OC-%-from-20D-Mean  NewColumn
# 160                 False      False
# 169                 False      False
# 237                 False      False
# 270                 False      False
# 275                 False      False
# ...                   ...        ...
# 12833               False      False
# 12842               False      False
# 12852               False      False
# 12939               False      False
# 13527               False      False
#
# [202 rows x 14 columns]

# %%
import pandas as pd
import numpy as np

def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(axis=1)
    return df[indices_to_keep].astype(np.float64)

# %%
X = prices[['O-to-C', 'OC-20D-Mean', 'Volume-20D-Mean', 'MaxOC_Prev10', 'Volume-%-from-20D-Mean', 'OC-%-from-20D-Mean']]
X
y = prices['NewColumn']

# %%
clean_dataset(X)
# Out:
# /var/folders/y1/gs_trwzd195f5bl9bb0dxstw0000gp/T/ipykernel_97798/2105942659.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#          O-to-C  OC-20D-Mean  Volume-20D-Mean  MaxOC_Prev10  \
# 19    -0.008991    -0.002762       2232377.15      0.007064
# 20    -0.008349    -0.003950       2310228.15      0.007064
# 21    -0.019267    -0.005042       2439655.40      0.007064
# 22    -0.026332    -0.006808       2609954.40      0.007064
# 23     0.011560    -0.005973       2759817.55      0.011560
# ...         ...          ...              ...           ...
# 13566  0.000000     0.107499      10938195.00      1.419998
# 13567 -1.380005     0.000499      11026190.00      1.419998
# 13568 -0.529999     0.000499      11240220.00      1.419998
# 13569  0.059998     0.055999      11061410.00      1.419998
# 13570  0.699997     0.007999      11148390.00      1.419998
#
#        Volume-%-from-20D-Mean  OC-%-from-20D-Mean
# 19                  56.931099          225.560014
# 20                  81.128907          111.374949
# 21                  91.463885          282.156637
# 22                  73.005207          286.791524
# 23                  76.304662         -293.541080
# ...                       ...                 ...
# 13566                1.513092         -100.000000
# 13567                2.076057      -276886.534047
# 13568               34.264276      -106320.183486
# 13569              -12.830281            7.140424
# 13570                6.856685         8651.430752
#
# [13523 rows x 6 columns]

# %%
#Using isna fuction to find "infinity" values
X.isna()
# Out:
#        O-to-C  OC-20D-Mean  Volume-20D-Mean  MaxOC_Prev10  \
# 19      False        False            False         False
# 20      False        False            False         False
# 21      False        False            False         False
# 22      False        False            False         False
# 23      False        False            False         False
# ...       ...          ...              ...           ...
# 13566   False        False            False         False
# 13567   False        False            False         False
# 13568   False        False            False         False
# 13569   False        False            False         False
# 13570   False        False            False         False
#
#        Volume-%-from-20D-Mean  OC-%-from-20D-Mean
# 19                      False               False
# 20                      False               False
# 21                      False               False
# 22                      False               False
# 23                      False               False
# ...                       ...                 ...
# 13566                   False               False
# 13567                   False               False
# 13568                   False               False
# 13569                   False               False
# 13570                   False               False
#
# [13550 rows x 6 columns]

# %%
#Using isnan function to find "infinity" values
np.isnan(X.any())
# Out:
# O-to-C                    False
# OC-20D-Mean               False
# Volume-20D-Mean           False
# MaxOC_Prev10              False
# Volume-%-from-20D-Mean    False
# OC-%-from-20D-Mean        False
# dtype: bool

# %%
#Using isfinite fuction to find "infinity" values
np.isfinite(X.all())
# Out:
# O-to-C                    True
# OC-20D-Mean               True
# Volume-20D-Mean           True
# MaxOC_Prev10              True
# Volume-%-from-20D-Mean    True
# OC-%-from-20D-Mean        True
# dtype: bool

# %%
#Still trying to remove infinite values, did not work
#X[np.isfinite(X) == True] = 0

# %%
#Still trying to remove infinite values
X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.fillna(999, inplace=True)

#FINALLY found the code to fix error under fit step which stated:
#"ValueError: Input contains NaN, infinity or a value too large for dtype('float64')"
# Out:
# /var/folders/y1/gs_trwzd195f5bl9bb0dxstw0000gp/T/ipykernel_97798/2193761838.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace([np.inf, -np.inf], np.nan, inplace=True)
# /var/folders/y1/gs_trwzd195f5bl9bb0dxstw0000gp/T/ipykernel_97798/2193761838.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.fillna(999, inplace=True)

# %%
# Display a sample of y
y[:5]
# Out:
# 19    0
# 20    0
# 21    0
# 22    0
# 23    0
# Name: NewColumn, dtype: int64

# %%
 from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs', random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
# Create scaler instance
X_scaler = StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a sequential neural network model
neuron = Sequential()

# %%
# Add the input and the hidden layer to the model
#number_inputs = 2
#number_hidden_nodes = 3

#neuron.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %%
# Define the the number of inputs to the model
number_inputs = 22

# Define the number of hidden nodes for the model
number_hidden_nodes = 12

# Add a Dense layer specifying the number of inputs, the number of hidden nodes, and the activation function
neuron.add(Dense(units=number_hidden_nodes, input_dim=number_inputs, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
neuron.add(Dense(1, activation="sigmoid"))

# %%
# Add the output layer
number_classes = 1

#neuron.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Display model summary
neuron.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 9
#
#  dense_1 (Dense)             (None, 1)                 4
#
#  dense_2 (Dense)             (None, 12)                24
#
#  dense_3 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 50 (200.00 Byte)
# Trainable params: 50 (200.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Compiling a neural network model
neuron.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
#Attempted to use this code to address error below

import tensorflow as tf

train_data = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))
valid_data = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))

# %%
# Fit the model using 100 epochs and the training data
model = neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 2
#       1 # Fit the model using 100 epochs and the training data
# ----> 2 model = neuron.fit(X_train_scaled, y_train, epochs=100)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/y1/gs_trwzd195f5bl9bb0dxstw0000gp/T/__autograph_generated_filei06rdab7.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/kaitywilkerson/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/kaitywilkerson/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/kaitywilkerson/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/kaitywilkerson/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 1150, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/kaitywilkerson/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/kaitywilkerson/anaconda3/lib/python3.11/site-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 2), found shape=(None, 6)
